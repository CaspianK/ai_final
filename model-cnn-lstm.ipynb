# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, Conv1D, Flatten
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
air_quality = pd.read_csv('Data/Almaty US Embassy Air Quality.csv')

weather_files = [
    'Data/Almaty Weather 2020-2021.csv',
    'Data/Almaty Weather 2021-2023.csv',
    'Data/Almaty Weather 2023-2024.csv'
]

weather_data = pd.concat((pd.read_csv(f) for f in weather_files), ignore_index=True)

# %%
print(air_quality.head())
print(air_quality.info())
# Out:
#        date  pm25  pm10  no2  so2  co
# 0  2024/4/1    59    43   13    1   6
# 1  2024/4/2    66    21   10    1   4
# 2  2024/4/3    39    31   10    1   4
# 3  2024/4/4    58    34   12    1   5
# 4  2024/4/5    63    27   10    1   3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1526 entries, 0 to 1525
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1526 non-null   object
#  1    pm25   1526 non-null   object
#  2    pm10   1526 non-null   object
#  3    no2    1526 non-null   object
#  4    so2    1526 non-null   object
#  5    co     1526 non-null   object
# dtypes: object(6)
# memory usage: 71.7+ KB
# None

# %%
print(weather_data.head())
print(weather_data.info())
# Out:
#                 name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Алматы, Қазақстан  2020-02-11      3.0     -6.2  -2.8           1.9
# 1  Алматы, Қазақстан  2020-02-12     -0.6     -7.0  -4.8          -3.1
# 2  Алматы, Қазақстан  2020-02-13      3.5     -6.0  -0.4           0.8
# 3  Алматы, Қазақстан  2020-02-14      3.6     -1.3   0.4           2.4
# 4  Алматы, Қазақстан  2020-02-15      2.0     -2.1  -0.7          -0.7
#
#    feelslikemin  feelslike  dew  humidity  ...  solarenergy  uvindex  \
# 0          -9.4       -6.0 -3.6      94.3  ...          9.1        4
# 1         -10.6       -7.5 -6.0      91.7  ...         12.5        6
# 2         -10.0       -3.9 -1.7      91.1  ...          5.4        3
# 3          -5.2       -2.7 -1.0      91.1  ...         12.7        6
# 4          -5.9       -3.9 -2.2      89.7  ...         12.9        6
#
#    severerisk              sunrise               sunset  moonphase  \
# 0         NaN  2020-02-11T07:57:06  2020-02-11T18:16:51       0.57
# 1         NaN  2020-02-12T07:55:46  2020-02-12T18:18:12       0.60
# 2         NaN  2020-02-13T07:54:24  2020-02-13T18:19:33       0.64
# 3         NaN  2020-02-14T07:53:01  2020-02-14T18:20:53       0.67
# 4         NaN  2020-02-15T07:51:37  2020-02-15T18:22:13       0.71
#
#                      conditions  \
# 0          Snow, Rain, Overcast
# 1                Snow, Overcast
# 2          Snow, Rain, Overcast
# 3  Snow, Rain, Partially cloudy
# 4              Partially cloudy
#
#                                          description               icon  \
# 0  Cloudy skies throughout the day with rain or s...               snow
# 1  Cloudy skies throughout the day with early mor...               snow
# 2  Cloudy skies throughout the day with afternoon...               snow
# 3  Partly cloudy throughout the day with rain or ...               snow
# 4                  Partly cloudy throughout the day.  partly-cloudy-day
#
#                                             stations
# 0  36883099999,36885099999,36871099999,UAAA,36872...
# 1  36883099999,36885099999,36871099999,UAAA,36872...
# 2  36883099999,36885099999,36871099999,UAAA,36872...
# 3  36883099999,36885099999,36871099999,UAAA,36872...
# 4  36883099999,36885099999,36871099999,UAAA,36872...
#
# [5 rows x 33 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1540 non-null   object
#  1   datetime          1540 non-null   object
#  2   tempmax           1540 non-null   float64
#  3   tempmin           1540 non-null   float64
#  4   temp              1540 non-null   float64
#  5   feelslikemax      1540 non-null   float64
#  6   feelslikemin      1540 non-null   float64
#  7   feelslike         1540 non-null   float64
#  8   dew               1540 non-null   float64
#  9   humidity          1540 non-null   float64
#  10  precip            1540 non-null   float64
#  11  precipprob        1540 non-null   int64
#  12  precipcover       1540 non-null   float64
#  13  preciptype        1006 non-null   object
#  14  snow              1540 non-null   float64
#  15  snowdepth         1540 non-null   float64
#  16  windgust          1540 non-null   float64
#  17  windspeed         1540 non-null   float64
#  18  winddir           1540 non-null   float64
#  19  sealevelpressure  1540 non-null   float64
#  20  cloudcover        1540 non-null   float64
#  21  visibility        1540 non-null   float64
#  22  solarradiation    1540 non-null   float64
#  23  solarenergy       1540 non-null   float64
#  24  uvindex           1540 non-null   int64
#  25  severerisk        841 non-null    float64
#  26  sunrise           1540 non-null   object
#  27  sunset            1540 non-null   object
#  28  moonphase         1540 non-null   float64
#  29  conditions        1540 non-null   object
#  30  description       1540 non-null   object
#  31  icon              1540 non-null   object
#  32  stations          1540 non-null   object
# dtypes: float64(22), int64(2), object(9)
# memory usage: 397.2+ KB
# None

# %%
air_quality['date'] = pd.to_datetime(air_quality['date'], format='%Y/%m/%d')

# %%
weather_data['datetime'] = pd.to_datetime(weather_data['datetime'])

# %%
merged_data = pd.merge(
    air_quality, 
    weather_data, 
    left_on='date', 
    right_on='datetime', 
    how='inner'
)

# %%
print(merged_data.isnull().sum())
# Out:
# date                  0
#  pm25                 0
#  pm10                 0
#  no2                  0
#  so2                  0
#  co                   0
# name                  0
# datetime              0
# tempmax               0
# tempmin               0
# temp                  0
# feelslikemax          0
# feelslikemin          0
# feelslike             0
# dew                   0
# humidity              0
# precip                0
# precipprob            0
# precipcover           0
# preciptype          528
# snow                  0
# snowdepth             0
# windgust              0
# windspeed             0
# winddir               0
# sealevelpressure      0
# cloudcover            0
# visibility            0
# solarradiation        0
# solarenergy           0
# uvindex               0
# severerisk          684
# sunrise               0
# sunset                0
# moonphase             0
# conditions            0
# description           0
# icon                  0
# stations              0
# dtype: int64

# %%
merged_data.columns = merged_data.columns.str.strip()

# %%
object_to_numerical = ['pm25', 'pm10', 'no2', 'so2', 'co']

for col in object_to_numerical:
    merged_data[col] = merged_data[col].str.strip()
    merged_data[col].replace('', np.nan, inplace=True)

# %%
print(merged_data.isnull().sum())
# Out:
# date                  0
# pm25                192
# pm10                334
# no2                 695
# so2                 280
# co                  274
# name                  0
# datetime              0
# tempmax               0
# tempmin               0
# temp                  0
# feelslikemax          0
# feelslikemin          0
# feelslike             0
# dew                   0
# humidity              0
# precip                0
# precipprob            0
# precipcover           0
# preciptype          528
# snow                  0
# snowdepth             0
# windgust              0
# windspeed             0
# winddir               0
# sealevelpressure      0
# cloudcover            0
# visibility            0
# solarradiation        0
# solarenergy           0
# uvindex               0
# severerisk          684
# sunrise               0
# sunset                0
# moonphase             0
# conditions            0
# description           0
# icon                  0
# stations              0
# dtype: int64

# %%
object_to_numerical = ['pm25', 'pm10', 'no2', 'so2', 'co']

for col in object_to_numerical:
    try:
        merged_data[col] = pd.to_numeric(merged_data[col])
    except ValueError:
        pass

# %%
merged_data['pm25'] = merged_data['pm25'].fillna(merged_data['pm25'].mean())
merged_data['pm10'] = merged_data['pm10'].fillna(merged_data['pm10'].mean())
merged_data['no2'] = merged_data['no2'].fillna(merged_data['no2'].mean())
merged_data['so2'] = merged_data['so2'].fillna(merged_data['so2'].mean())
merged_data['co'] = merged_data['co'].fillna(merged_data['co'].mean())
merged_data = merged_data.drop(columns=['preciptype', 'severerisk', 'name', 'sunrise', 'sunset', 'description', 'icon', 'stations'])

# %%
merged_data = merged_data.drop_duplicates()

# %%
print(merged_data.isnull().sum())
# Out:
# date                0
# pm25                0
# pm10                0
# no2                 0
# so2                 0
# co                  0
# datetime            0
# tempmax             0
# tempmin             0
# temp                0
# feelslikemax        0
# feelslikemin        0
# feelslike           0
# dew                 0
# humidity            0
# precip              0
# precipprob          0
# precipcover         0
# snow                0
# snowdepth           0
# windgust            0
# windspeed           0
# winddir             0
# sealevelpressure    0
# cloudcover          0
# visibility          0
# solarradiation      0
# solarenergy         0
# uvindex             0
# moonphase           0
# conditions          0
# dtype: int64

# %%
target = 'pm25'

features = ['temp', 'humidity', 'windspeed', 'winddir', 'precip', 'pm10', 'no2', 'so2', 'co']

# %%
merged_data.sort_values('date', inplace=True)

merged_data.reset_index(drop=True, inplace=True)

# Define split sizes
train_size = int(len(merged_data) * 0.6)        # 60% Training
validation_size = int(len(merged_data) * 0.2)   # 20% Validation
test_size = len(merged_data) - train_size - validation_size  # 20% Test

# Perform the splits
train_data = merged_data.iloc[:train_size]
validation_data = merged_data.iloc[train_size:train_size + validation_size]
test_data = merged_data.iloc[train_size + validation_size:]

# %%
# Endogenous variable (target)
y_train = train_data[target]
y_validation = validation_data[target]
y_test = test_data[target]

# Exogenous variables (features)
exog_train = train_data[features]
exog_validation = validation_data[features]
exog_test = test_data[features]

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series, title=''):
    result = adfuller(series.dropna())
    print(f'ADF Statistic for {title}: {result[0]}')
    print(f'p-value: {result[1]}')

adf_test(y_train, title=target)
# Out:
# ADF Statistic for pm25: -3.093915147197574
# p-value: 0.02700678427569794

# %%
p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))

best_aic = np.inf
best_order = None

for order in pdq:
    try:
        model = SARIMAX(
            y_train, 
            exog=exog_train, 
            order=order, 
            enforce_stationarity=False, 
            enforce_invertibility=False
        )
        results = model.fit(disp=False)
        if results.aic < best_aic:
            best_aic = results.aic
            best_order = order
    except:
        continue

print(f'Best ARIMAX order: {best_order} with AIC: {best_aic}')
# Out:
# Best ARIMAX order: (1, 1, 2) with AIC: 8229.902895143072

# %%
model_arimax = SARIMAX(
    y_train, 
    exog=exog_train, 
    order=best_order, 
    enforce_stationarity=False, 
    enforce_invertibility=False
)
arimax_result = model_arimax.fit()

# Print summary
print(arimax_result.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           13     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.49811D+00    |proj g|=  1.33065D-01
#
# At iterate    5    f=  4.48768D+00    |proj g|=  1.22460D-01
#  This problem is unconstrained.
# At iterate   10    f=  4.48624D+00    |proj g|=  2.74169D-02
#
# At iterate   15    f=  4.48555D+00    |proj g|=  3.61993D-02
#
# At iterate   20    f=  4.48505D+00    |proj g|=  1.11976D-02
#
# At iterate   25    f=  4.48337D+00    |proj g|=  1.24827D-02
#
# At iterate   30    f=  4.48319D+00    |proj g|=  1.55569D-02
#
# At iterate   35    f=  4.48311D+00    |proj g|=  1.58055D-03
#
# At iterate   40    f=  4.48306D+00    |proj g|=  2.20433D-02
#
# At iterate   45    f=  4.48302D+00    |proj g|=  1.16731D-03
#
# At iterate   50    f=  4.48301D+00    |proj g|=  7.04504D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    13     50     55      1     0     0   7.045D-04   4.483D+00
#   F =   4.4830070465262688
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   pm25   No. Observations:                  915
# Model:               SARIMAX(1, 1, 2)   Log Likelihood               -4101.951
# Date:                Wed, 25 Dec 2024   AIC                           8229.903
# Time:                        10:25:17   BIC                           8292.492
# Sample:                             0   HQIC                          8253.798
#                                 - 915
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# temp          -1.2064      0.286     -4.220      0.000      -1.767      -0.646
# humidity      -0.0702      0.090     -0.776      0.437      -0.247       0.107
# windspeed     -0.6141      0.127     -4.839      0.000      -0.863      -0.365
# winddir        0.0249      0.008      3.235      0.001       0.010       0.040
# precip        -1.2294      0.164     -7.501      0.000      -1.551      -0.908
# pm10           0.0945      0.038      2.501      0.012       0.020       0.169
# no2           -0.2389      0.126     -1.892      0.058      -0.486       0.009
# so2           -0.5851      0.397     -1.473      0.141      -1.363       0.193
# co             0.2075      0.195      1.064      0.288      -0.175       0.590
# ar.L1          0.2875      0.068      4.219      0.000       0.154       0.421
# ma.L1         -0.7548      0.073    -10.306      0.000      -0.898      -0.611
# ma.L2         -0.1283      0.058     -2.229      0.026      -0.241      -0.016
# sigma2       480.0032     18.201     26.373      0.000     444.330     515.676
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                93.23
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.93   Skew:                             0.04
# Prob(H) (two-sided):                  0.52   Kurtosis:                         4.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Predict on Validation Set
arimax_val_pred = arimax_result.predict(
    start=train_size,
    end=train_size + validation_size - 1,
    exog=exog_validation
)

# Forecast on Test Set
arimax_test_pred = arimax_result.forecast(
    steps=test_size,
    exog=exog_test
)

# %%
# Initialize scalers
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Fit scaler on Training Features and Target
scaled_train_features = feature_scaler.fit_transform(train_data[features])
scaled_train_target = target_scaler.fit_transform(train_data[[target]])

# Transform Validation and Test Features and Target
scaled_validation_features = feature_scaler.transform(validation_data[features])
scaled_validation_target = target_scaler.transform(validation_data[[target]])

scaled_test_features = feature_scaler.transform(test_data[features])
scaled_test_target = target_scaler.transform(test_data[[target]])

# Combine Scaled Features and Target for Sequence Creation
scaled_train = np.hstack((scaled_train_features, scaled_train_target))
scaled_validation = np.hstack((scaled_validation_features, scaled_validation_target))
scaled_test = np.hstack((scaled_test_features, scaled_test_target))

# %%
def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length, :-1])  # Features
        y.append(data[i+seq_length, -1])     # Target
    return np.array(X), np.array(y)

seq_length = 5  # Number of time steps

# Create Sequences
X_train_lstm, y_train_lstm = create_sequences(scaled_train, seq_length)
X_validation_lstm, y_validation_lstm = create_sequences(scaled_validation, seq_length)
X_test_lstm, y_test_lstm = create_sequences(scaled_test, seq_length)

# %%
# Define the LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(50, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])))
model_lstm.add(Dense(1))
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model_lstm.fit(
    X_train_lstm, y_train_lstm, 
    epochs=20, 
    batch_size=64, 
    validation_data=(X_validation_lstm, y_validation_lstm),
    verbose=1
)
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0318 - val_loss: 0.0133
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0140 - val_loss: 0.0133
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125 - val_loss: 0.0110
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - val_loss: 0.0102
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - val_loss: 0.0103
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - val_loss: 0.0097
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0098 - val_loss: 0.0094
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - val_loss: 0.0117
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - val_loss: 0.0094
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - val_loss: 0.0088
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - val_loss: 0.0104
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - val_loss: 0.0102
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - val_loss: 0.0107
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - val_loss: 0.0134
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - val_loss: 0.0100
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - val_loss: 0.0096

# %%
# Predict on Validation and Test Data
lstm_val_pred = model_lstm.predict(X_validation_lstm)
lstm_test_pred = model_lstm.predict(X_test_lstm)

# Inverse Transform Predictions
lstm_val_pred_rescaled = target_scaler.inverse_transform(lstm_val_pred)
lstm_test_pred_rescaled = target_scaler.inverse_transform(lstm_test_pred)

# Inverse Transform Actual Values
y_validation_rescaled = target_scaler.inverse_transform(y_validation_lstm.reshape(-1, 1))
y_test_rescaled = target_scaler.inverse_transform(y_test_lstm.reshape(-1, 1))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step

# %%
model_cnn = Sequential()

# First Conv1D layer
model_cnn.add(
    Conv1D(
        filters=64,
        kernel_size=2,
        activation='relu',
        input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])
    )
)

# %%
model_cnn.add(Flatten())

# Fully connected layer
model_cnn.add(Dense(50, activation='relu'))

# Output layer for regression (predicting PM2.5)
model_cnn.add(Dense(1))

model_cnn.compile(optimizer='adam', loss='mean_squared_error')

# %%
history_cnn = model_cnn.fit(
    X_train_lstm, y_train_lstm,   # same sequences as LSTM
    epochs=20,
    batch_size=64,
    validation_data=(X_validation_lstm, y_validation_lstm),
    verbose=1
)
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0508 - val_loss: 0.0173
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0178 - val_loss: 0.0191
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0140 - val_loss: 0.0108
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0088 - val_loss: 0.0108
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077 - val_loss: 0.0117
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077 - val_loss: 0.0121
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0073 - val_loss: 0.0116
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - val_loss: 0.0126
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - val_loss: 0.0130
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0104
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0120
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0055 - val_loss: 0.0096
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0101
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0099
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0054 - val_loss: 0.0088
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0053 - val_loss: 0.0103
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0050 - val_loss: 0.0092
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0053 - val_loss: 0.0093
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0051 - val_loss: 0.0084

# %%
cnn_val_pred = model_cnn.predict(X_validation_lstm)
cnn_test_pred = model_cnn.predict(X_test_lstm)

cnn_val_pred_rescaled = target_scaler.inverse_transform(cnn_val_pred)
cnn_test_pred_rescaled = target_scaler.inverse_transform(cnn_test_pred)

y_cnn_validation_rescaled = target_scaler.inverse_transform(y_validation_lstm.reshape(-1, 1))
y_cnn_test_rescaled = target_scaler.inverse_transform(y_test_lstm.reshape(-1, 1))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step

# %%
meta_cnn_features_val = np.column_stack((
    cnn_val_pred_rescaled.flatten(), 
    lstm_val_pred_rescaled.flatten()
))

y_cnn_meta_val = y_cnn_validation_rescaled.flatten()

# Train meta-model
meta_cnn_model = LinearRegression()
meta_cnn_model.fit(meta_cnn_features_val, y_cnn_meta_val)
# Out:
# LinearRegression()

# %%
meta_cnn_features_test = np.column_stack((
    cnn_test_pred_rescaled.flatten(), 
    lstm_test_pred_rescaled.flatten()
))

hybrid_cnn_predictions = meta_cnn_model.predict(meta_cnn_features_test)

# %%
# Prepare Meta-Features from Validation Set
arimax_val_pred = arimax_val_pred.iloc[seq_length:].values
arimax_test_pred = arimax_test_pred.iloc[seq_length:].values

meta_features_val = np.column_stack((arimax_val_pred, lstm_val_pred_rescaled.flatten()))
y_meta_val = y_validation_rescaled.flatten()

# Initialize and Train the Meta-Model
meta_model = LinearRegression()
meta_model.fit(meta_features_val, y_meta_val)
# Out:
# LinearRegression()

# %%
# Prepare Meta-Features from Test Set
meta_features_test = np.column_stack((arimax_test_pred, lstm_test_pred_rescaled.flatten()))

# Make Hybrid Predictions
hybrid_predictions = meta_model.predict(meta_features_test)

# %%
# ARIMAX Evaluation
arimax_rmse = np.sqrt(mean_squared_error(y_test_rescaled, arimax_test_pred))
arimax_mae = mean_absolute_error(y_test_rescaled, arimax_test_pred)

# LSTM Evaluation
lstm_rmse = np.sqrt(mean_squared_error(y_test_rescaled, lstm_test_pred_rescaled))
lstm_mae = mean_absolute_error(y_test_rescaled, lstm_test_pred_rescaled)

# Hybrid ARIMAX-LSTM Model Evaluation
hybrid_rmse = np.sqrt(mean_squared_error(y_test_rescaled, hybrid_predictions))
hybrid_mae = mean_absolute_error(y_test_rescaled, hybrid_predictions)

# Hybrid CNN-LSTM Model Evaluation
hybrid_cnn_rmse = np.sqrt(mean_squared_error(y_cnn_test_rescaled, hybrid_cnn_predictions))
hybrid_cnn_mae = mean_absolute_error(y_cnn_test_rescaled, hybrid_cnn_predictions)

print(f"ARIMAX RMSE: {arimax_rmse:.2f}, MAE: {arimax_mae:.2f}")
print(f"LSTM RMSE: {lstm_rmse:.2f}, MAE: {lstm_mae:.2f}")
print(f"Hybrid ARIMAX-LSTM RMSE: {hybrid_rmse:.2f}, MAE: {hybrid_mae:.2f}")
print(f"Hybrid CNN-LSTM RMSE: {hybrid_cnn_rmse:.2f}, MAE: {hybrid_cnn_mae:.2f}")
# Out:
# ARIMAX RMSE: 35.03, MAE: 31.61
# LSTM RMSE: 21.53, MAE: 17.32
# Hybrid ARIMAX-LSTM RMSE: 17.83, MAE: 13.95
# Hybrid CNN-LSTM RMSE: 19.10, MAE: 15.23

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test_rescaled, label='Actual', color='black')
plt.plot(arimax_test_pred, label='ARIMAX Predictions', color='blue')
plt.plot(lstm_test_pred_rescaled, label='LSTM Predictions', color='green')
plt.plot(hybrid_predictions, label='Hybrid ARIMAX-LSTM Predictions', color='red')
plt.plot(hybrid_cnn_predictions, label='Hybrid CNN-LSTM Predictions', color='orange')
plt.legend()
plt.title('Actual vs. ARIMAX, LSTM, Hybrid ARIMAX-LSTM, and Hybrid CNN-LSTM Predictions')
plt.xlabel('Time')
plt.ylabel('PM2.5 Concentration')
plt.show()

# %%
def get_recommendation(pm25):
    if pm25 <= 12:
        return "Air quality is good. No actions needed."
    elif 12 < pm25 <= 35:
        return "Air quality is moderate. Sensitive individuals should limit prolonged outdoor activities."
    elif 35 < pm25 <= 55:
        return "Air quality is unhealthy for sensitive groups. Consider wearing a mask outdoors."
    elif 55 < pm25 <= 150:
        return "Air quality is unhealthy. Everyone should limit outdoor activities."
    else:
        return "Air quality is hazardous. Stay indoors, use air purifiers, and avoid exposure."

# %%
hybrid_recommendations = [get_recommendation(pred) for pred in hybrid_predictions]

# %%
for i in range(5):
    prediction_date = test_data.iloc[i]['date'].strftime('%Y-%m-%d')
    print(f"Date: {prediction_date}")
    print(f"  Hybrid ARIMAX-LSTM Prediction: {hybrid_predictions[i]:.2f}, Recommendation: {hybrid_recommendations[i]}")
# Out:
# Date: 2023-06-30
#   Hybrid ARIMAX-LSTM Prediction: 39.26, Recommendation: Air quality is unhealthy for sensitive groups. Consider wearing a mask outdoors.
# Date: 2023-07-01
#   Hybrid ARIMAX-LSTM Prediction: 46.85, Recommendation: Air quality is unhealthy for sensitive groups. Consider wearing a mask outdoors.
# Date: 2023-07-02
#   Hybrid ARIMAX-LSTM Prediction: 41.41, Recommendation: Air quality is unhealthy for sensitive groups. Consider wearing a mask outdoors.
# Date: 2023-07-03
#   Hybrid ARIMAX-LSTM Prediction: 44.31, Recommendation: Air quality is unhealthy for sensitive groups. Consider wearing a mask outdoors.
# Date: 2023-07-04
#   Hybrid ARIMAX-LSTM Prediction: 45.28, Recommendation: Air quality is unhealthy for sensitive groups. Consider wearing a mask outdoors.

# %%
specific_dates = ['2024-04-07', '2024-01-19']

filtered_data = test_data[test_data['date'].dt.date.isin(pd.to_datetime(specific_dates).date)]

# Extract the corresponding row numbers (relative positions) for predictions
filtered_relative_indices = filtered_data.index - test_data.index[0]

# Display predictions and recommendations for these specific dates
for idx, rel_idx in zip(filtered_data.index, filtered_relative_indices):
    prediction_date = test_data.loc[idx, 'date'].date()  # Extract date part
    print(f"Date: {prediction_date}")
    print(f"  Hybrid Prediction: {hybrid_predictions[rel_idx]:.2f}, Recommendation: {hybrid_recommendations[rel_idx]}")
# Out:
# Date: 2024-01-19
#   Hybrid Prediction: 151.23, Recommendation: Air quality is hazardous. Stay indoors, use air purifiers, and avoid exposure.
# Date: 2024-04-07
#   Hybrid Prediction: 58.60, Recommendation: Air quality is unhealthy. Everyone should limit outdoor activities.
